# %% [markdown]
# # sequence lengths ?

# %%
import pandas as pd
import os

# %%
# base level

path = "/nfs/scratch/pinder/negative_dataset/my_repository/datasets/no_duplicates"
df = pd.concat([
    pd.read_csv(os.path.join(path, split + ".csv")) for split in ['train', 'val', 'test']
])

print(df[(df["receptor_seq"].str.len() <= 5) & (df["ligand_seq"].str.len() <= 5)])
# Out:
#                                          entry  split  label receptor_seq  \
# 5193    3dox__B1_UNDEFINED--3dox__C1_UNDEFINED  train      1         SQNY
# 24742   7q9h__D1_UNDEFINED--7q9h__C1_UNDEFINED  train      1        AVAEK
# 24743   7q9c__C1_UNDEFINED--7q9c__D1_UNDEFINED  train      1          RLS
# 31532   7xeb__C1_UNDEFINED--7xeb__D1_UNDEFINED  train      1          GPP
# 32308   5zs3__B1_UNDEFINED--5zs3__B8_UNDEFINED  train      1        GRLLP
# ...                                        ...    ...    ...          ...
# 175248  2oxz__C1_UNDEFINED--2oxz__B1_UNDEFINED  train      1          IAG
# 176501  1p11__B1_UNDEFINED--1p11__C1_UNDEFINED  train      1         AAPA
# 178577  4f73__C1_UNDEFINED--4f73__D1_UNDEFINED  train      1         ARVL
# 180175  4pyw__B1_UNDEFINED--4pyw__C1_UNDEFINED  train      1         TTAI
# 180361  7qff__C1_UNDEFINED--7qff__D1_UNDEFINED  train      1         VACK
#
#        ligand_seq                                      receptor_path  \
# ...

# %%
# deleak level

path = "/nfs/scratch/pinder/negative_dataset/my_repository/datasets/no_duplicates/deleak_cdhit"
df = pd.concat([
    pd.read_csv(os.path.join(path, split + ".csv")) for split in ['train', 'val', 'test']
])

print(f"Is df empty?: {df.empty}")

print(df[(df["receptor_seq"].str.len() <= 5) & (df["ligand_seq"].str.len() <= 5)])
# Out:
# Is df empty?: False
# Empty DataFrame
# Columns: [entry, split, label, receptor_seq, ligand_seq, receptor_path, ligand_path, class]
# Index: []

# %%
# uniprot level

path = "/nfs/scratch/pinder/negative_dataset/my_repository/datasets/no_duplicates/uniprot"
df = pd.concat([
    pd.read_csv(os.path.join(path, split + ".csv")) for split in ['train', 'val', 'test']
])

print(f"Is df empty?: {df.empty}")

print(df[(df["receptor_seq"].str.len() <= 5) & (df["ligand_seq"].str.len() <= 5)])
# Out:
# Is df empty?: False
#                                          entry  split  label receptor_seq  \
# 5161    3dox__B1_UNDEFINED--3dox__C1_UNDEFINED  train      1         SQNY
# 24509   7q9h__D1_UNDEFINED--7q9h__C1_UNDEFINED  train      1        AVAEK
# 24510   7q9c__C1_UNDEFINED--7q9c__D1_UNDEFINED  train      1          RLS
# 31240   7xeb__C1_UNDEFINED--7xeb__D1_UNDEFINED  train      1          GPP
# 32013   5zs3__B1_UNDEFINED--5zs3__B8_UNDEFINED  train      1        GRLLP
# ...                                        ...    ...    ...          ...
# 172895  2oxz__C1_UNDEFINED--2oxz__B1_UNDEFINED  train      1          IAG
# 174137  1p11__B1_UNDEFINED--1p11__C1_UNDEFINED  train      1         AAPA
# 176202  4f73__C1_UNDEFINED--4f73__D1_UNDEFINED  train      1         ARVL
# 177783  4pyw__B1_UNDEFINED--4pyw__C1_UNDEFINED  train      1         TTAI
# 177969  7qff__C1_UNDEFINED--7qff__D1_UNDEFINED  train      1         VACK
#
# ...

# %%
# uniprot deleak level

path = "/nfs/scratch/pinder/negative_dataset/my_repository/datasets/no_duplicates/uniprot/deleak_cdhit"
df = pd.concat([
    pd.read_csv(os.path.join(path, split + ".csv")) for split in ['train', 'val', 'test']
])

print(f"Is df empty?: {df.empty}")

print(df[(df["receptor_seq"].str.len() <= 5) & (df["ligand_seq"].str.len() <= 5)])
# Out:
# Is df empty?: False
# Empty DataFrame
# Columns: [entry, split, label, receptor_seq, ligand_seq, receptor_path, ligand_path, class]
# Index: []
